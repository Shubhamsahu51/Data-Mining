# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubhamsahu51/Data-Mining/blob/main/MIT2020051_Lab_Assigment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import itertools

data_set = pd.read_csv("/content/store_data.csv",header= None)

data_records = [] 
row,col = data_set.shape

for i in range(row):
  data_records.append([str(data_set.values[i,j]) for j in range(col)])

items = [] 
for sublist in data_records:
  for item in sublist:
    if (item!='nan'):
      items.append(item)

items.sort()
items
# Out:
# [' asparagus',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
#  'almonds',
# ...

# %%
minimum_support_count = 40

def single_item_frequency(items, minimum_support_count):
    c1 = {i:items.count(i) for i in items}
    l1 = {}
    for key, value in c1.items():
        if value >= minimum_support_count:
           l1[key] = value 
    
    return c1, l1

# %%
def pair_item_frequency(l1, data_records, minimum_support_count):
    l1 = sorted(list(l1.keys()))
    L1 = list(itertools.combinations(l1, 2))
    c2 = {}
    l2 = {}
    for iter1 in L1:
        count = 0
        for iter2 in data_records:
            if sublist(iter1, iter2):
                count+=1
        c2[iter1] = count
    for key, value in c2.items():
        if value >= minimum_support_count:
            if check_subset_frequency(key, l1, 1):
                l2[key] = value 
    
    return c2, l2

# %%
def three_item_frequency(l2, data_records, minimum_support_count):
    l2 = list(l2.keys())
    L2 = sorted(list(set([item for t in l2 for item in t])))
    L2 = list(itertools.combinations(L2, 3))
    c3 = {}
    l3 = {}
    for iter1 in L2:
        count = 0
        for iter2 in data_records:
            if sublist(iter1, iter2):
                count+=1
        c3[iter1] = count
    for key, value in c3.items():
        if value >= minimum_support_count:
            if check_subset_frequency(key, l2, 2):
                l3[key] = value 
        
    return c3, l3

# %%
def four_item_frequency(l3, data_records, minimum_support_count):
    l3 = list(l3.keys())
    L3 = sorted(list(set([item for t in l3 for item in t])))
    L3 = list(itertools.combinations(L3, 4))
    c4 = {}
    l4 = {}
    for iter1 in L3:
        count = 0
        for iter2 in data_records:
            if sublist(iter1, iter2):
                count+=1
        c4[iter1] = count
    for key, value in c4.items():
        if value >= minimum_support_count:
            if check_subset_frequency(key, l3, 3):
                l4[key] = value 
        
    return c4, l4

def sublist(lst1, lst2):
    return set(lst1) <= set(lst2)
    
def check_subset_frequency(itemset, l, n):
    if n>1:    
        subsets = list(itertools.combinations(itemset, n))
    else:
        subsets = itemset
    for iter1 in subsets:
        if not iter1 in l:
            return False
    return True


c1, l1 = single_item_frequency(items, minimum_support_count)
c2, l2 = pair_item_frequency(l1, data_records, minimum_support_count)
c3, l3 = three_item_frequency(l2, data_records, minimum_support_count)
c4, l4 = four_item_frequency(l3, data_records, minimum_support_count)
print("L1 => ", l1)
print("L2 => ", l2)
print("L3 => ", l3)
print("L4 => ", l4)
# Out:
# L1 =>  {'almonds': 153, 'antioxydant juice': 67, 'avocado': 250, 'bacon': 65, 'barbecue sauce': 81, 'black tea': 107, 'blueberries': 69, 'body spray': 86, 'brownies': 253, 'bug spray': 65, 'burger sauce': 44, 'burgers': 654, 'butter': 226, 'cake': 608, 'candy bars': 73, 'carrots': 115, 'cereals': 193, 'champagne': 351, 'chicken': 450, 'chili': 46, 'chocolate': 1230, 'cider': 79, 'clothes accessories': 63, 'cookies': 603, 'cooking oil': 383, 'cottage cheese': 239, 'eggplant': 99, 'eggs': 1348, 'energy bar': 203, 'energy drink': 200, 'escalope': 595, 'extra dark chocolate': 90, 'flax seed': 68, 'french fries': 1282, 'french wine': 169, 'fresh bread': 323, 'fresh tuna': 167, 'fromage blanc': 102, 'frozen smoothie': 475, 'frozen vegetables': 715, 'gluten free bar': 52, 'grated cheese': 393, 'green beans': 65, 'green grapes': 68, 'green tea': 991, 'ground beef': 737, 'gums': 101, 'ham': 203, 'herb & pepper': 371, 'honey': 356, 'hot dogs': 243, 'light cream': 117, 'light mayo': 204, 'low f
# ...

# %% [markdown]
# # ASSOCIATION RULE (Confidence=40%)

# %%
itemlist = {**l1, **l2, **l3, **l4}

def support_count(itemset, itemlist):
    return itemlist[itemset]

sets = []
for iter1 in list(l3.keys()):
    subsets = list(itertools.combinations(iter1, 2))
    sets.append(subsets)

list_l3 = list(l3.keys())
for i in range(0, len(list_l3)):
    for iter1 in sets[i]:
        a = iter1
        b = set(list_l3[i]) - set(iter1)
        confidence = (support_count(list_l3[i], itemlist)/support_count(iter1, itemlist))*100
        if (confidence >= 40):
          print("{}  ->  {} confidence = {}".format(a, b, confidence))
# Out:
# ('burgers', 'french fries')  ->  {'eggs'} confidence = 41.21212121212121
# ('burgers', 'ground beef')  ->  {'mineral water'} confidence = 44.44444444444444
# ('burgers', 'ground beef')  ->  {'spaghetti'} confidence = 45.55555555555556
# ('cake', 'chocolate')  ->  {'mineral water'} confidence = 41.17647058823529
# ('cake', 'milk')  ->  {'mineral water'} confidence = 48.0
# ('chicken', 'chocolate')  ->  {'mineral water'} confidence = 51.81818181818182
# ('chicken', 'milk')  ->  {'mineral water'} confidence = 45.04504504504504
# ('chicken', 'spaghetti')  ->  {'mineral water'} confidence = 40.310077519379846
# ('chocolate', 'cooking oil')  ->  {'mineral water'} confidence = 42.15686274509804
# ('chocolate', 'eggs')  ->  {'mineral water'} confidence = 40.562248995983936
# ('chocolate', 'frozen vegetables')  ->  {'mineral water'} confidence = 42.44186046511628
# ('chocolate', 'ground beef')  ->  {'mineral water'} confidence = 47.398843930635834
# ...
